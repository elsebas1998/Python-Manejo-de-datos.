# %% [markdown]
# Manejo de datos

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
inmuebles = pd.read_csv('/content/drive/MyDrive/Estudios Python/inmuebles_bogota.csv')
inmuebles.head()
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Baños  Área              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#              Valor
# 0    $ 360.000.000
# 1    $ 670.000.000
# 2  $ 1.120.000.000
# ...

# %%
inmuebles.shape
# Out:
# (9520, 8)

# %%
inmuebles.columns
# Out:
# Index(['Tipo', 'Descripcion', 'Habitaciones', 'Baños', 'Área', 'Barrio', 'UPZ',
#        'Valor'],
#       dtype='object')

# %% [markdown]
# Tratamiento de nombre de columnas

# %%
columnas = {'Baños': 'Banos', 'Área':'Area' }
inmuebles = inmuebles.rename(columns=columnas)
inmuebles.sample(5)
# Out:
#              Tipo                         Descripcion  Habitaciones  Banos  \
# 7376  Apartamento        Apartamento en venta en Bosa             3      1
# 665   Apartamento    Apartamento en venta en Engativa             2      2
# 940   Apartamento     Apartamento en venta en Usaquén             3      3
# 9081  Apartamento  Apartamento en venta en El Refugio             2      3
# 8666  Apartamento    Apartamento en venta en Fontibón             3      2
#
#       Area      Barrio                                 UPZ            Valor
# 7376    42        Bosa                        Bosa Central    $ 116.000.000
# 665     48    Engativa                            Engativá    $ 210.000.000
# 940    138     Usaquén                             Usaquén  $ 1.295.000.000
# 9081   261  El Refugio  CHAPINERO: Chicó Lago + El Refugio  $ 2.000.000.000
# 8666    70    Fontibón                            Fontibón    $ 214.900.000

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 595.1+ KB

# %% [markdown]
# Dtype = Objeto -> String,
#         int64 -> Entero

# %%
inmuebles.iloc[250]
# Out:
# Tipo                                                  Apartamento
# Descripcion                Apartamento en venta en Nueva Zelandia
# Habitaciones                                                    2
# Banos                                                           2
# Area                                                           56
# Barrio                                             Nueva Zelandia
# UPZ             SUBA: La Academia + Guaymaral + San José de Ba...
# Valor                                               $ 342.514.000
# Name: 250, dtype: object

# %%
inmuebles.iloc[205:260]
# Out:
#             Tipo                                 Descripcion  Habitaciones  \
# 205  Apartamento         Apartamento en venta en Bella Suiza             2
# 206  Apartamento       Apartamento en venta en Santa Barbara             5
# 207  Apartamento            Apartamento en venta en Engativa             3
# 208  Apartamento         Apartamento en venta en Bella Suiza             2
# 209  Apartamento       Apartamento en venta en Santa Barbara             2
# 210  Apartamento             Apartamento en venta en Usaquén             2
# 211  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 212  Apartamento    Apartamento en venta en Colina Campestre             3
# 213  Apartamento           Apartamento en venta en Chapinero             2
# 214  Apartamento           Apartamento en venta en Chapinero             3
# 215  Apartamento            Apartamento en venta en Cedritos             3
# ...

# %%
inmuebles['Valor'][277:300]
# Out:
# 277    $ 1.700.000.000
# 278      $ 570.000.000
# 279      $ 460.000.000
# 280      $ 960.000.000
# 281      $ 510.000.000
# 282      $ 520.000.000
# 283      $ 142.000.000
# 284      $ 750.000.000
# 285      $ 160.000.000
# 286      $ 445.000.000
# 287      $ 570.000.000
# 288      $ 319.981.523
# 289      $ 510.000.000
# 290      $ 380.000.000
# 291      $ 134.000.000
# 292      $ 120.000.000
# 293      $ 460.000.000
# 294      $ 560.000.000
# 295      $ 351.000.000
# 296    $ 1.390.000.000
# 297      $ 422.000.000
# 298      $ 260.000.000
# 299      $ 980.000.000
# Name: Valor, dtype: object

# %%
type(inmuebles['Valor'][100:200])
# Out:
# pandas.core.series.Series

# %%
inmuebles.Area.mean()
# Out:
# 146.66470588235293

# %%
inmuebles.Barrio == 'Engativa'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9515    False
# 9516    False
# 9517    False
# 9518     True
# 9519    False
# Name: Barrio, Length: 9520, dtype: bool

# %%
sum(inmuebles.Barrio == 'Engativa')
# Out:
# 462

# %%
inmuebles_Engativa	=(inmuebles.Barrio == 'Engativa')
Engativa_reservado	= inmuebles[inmuebles_Engativa]
Engativa_reservado
# Out:
#              Tipo                       Descripcion  Habitaciones  Banos  \
# 32    Apartamento  Apartamento en venta en Engativa             3      2
# 64    Apartamento  Apartamento en venta en Engativa             3      2
# 91    Apartamento  Apartamento en venta en Engativa             2      2
# 119   Apartamento  Apartamento en venta en Engativa             3      2
# 129   Apartamento  Apartamento en venta en Engativa             2      2
# ...           ...                               ...           ...    ...
# 9429         Casa         Casa en venta en Engativa             8      4
# 9435         Casa         Casa en venta en Engativa             8      4
# 9483         Casa         Casa en venta en Engativa             4      3
# 9503  Apartamento  Apartamento en venta en Engativa             3      2
# 9518         Casa         Casa en venta en Engativa             3      2
#
#       Area    Barrio       UPZ          Valor
# ...

# %%
Engativa_reservado.count
# Out:
# <bound method DataFrame.count of              Tipo                       Descripcion  Habitaciones  Banos  \
# 32    Apartamento  Apartamento en venta en Engativa             3      2
# 64    Apartamento  Apartamento en venta en Engativa             3      2
# 91    Apartamento  Apartamento en venta en Engativa             2      2
# 119   Apartamento  Apartamento en venta en Engativa             3      2
# 129   Apartamento  Apartamento en venta en Engativa             2      2
# ...           ...                               ...           ...    ...
# 9429         Casa         Casa en venta en Engativa             8      4
# 9435         Casa         Casa en venta en Engativa             8      4
# 9483         Casa         Casa en venta en Engativa             4      3
# 9503  Apartamento  Apartamento en venta en Engativa             3      2
# 9518         Casa         Casa en venta en Engativa             3      2
#
#       Area    Barrio       UPZ          Valor
# ...

# %%
Engativa_reservado.Area.mean()
# Out:
# 129.45454545454547

# %%
len(inmuebles.Barrio.value_counts())
# Out:
# 149

# %%
inmuebles.Barrio.value_counts()
# Out:
# Usaquén               1105
# Zona Noroccidental     877
# Bosa                   589
# Kennedy                589
# Cedritos               554
#                       ...
# Colinas De Suba          1
# La Estanzuela            1
# Roma                     1
# Alameda                  1
# Prado Veraniego          1
# Name: Barrio, Length: 149, dtype: int64

# %% [markdown]
# G R A F I C O S

# %%
inmuebles_barrios = inmuebles.Barrio.value_counts()
inmuebles_barrios.head(10).plot.bar()
# Out:
# <Axes: >

# %%
inmuebles_barrios.sample(10).plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# Promedio de area de todos los inmuebles en los barrios, mostrar top 10

# %%
print(inmuebles_barrios)
# Out:
# Usaquén               1105
# Zona Noroccidental     877
# Bosa                   589
# Kennedy                589
# Cedritos               554
#                       ...
# Colinas De Suba          1
# La Estanzuela            1
# Roma                     1
# Alameda                  1
# Prado Veraniego          1
# Name: Barrio, Length: 149, dtype: int64

# %%
area_barrios = inmuebles.groupby('Barrio')['Area'].mean()
print(area_barrios)
# Out:
# Barrio
# Alameda                97.000000
# Alhambra              190.411765
# Andes Norte           124.857143
# Antonio Nariño        163.062500
# Barrancas              70.200000
#                          ...
# Villa Maria           207.153846
# Villas De Granada      86.590909
# Villemar               76.888889
# Zona Franca            54.000000
# Zona Noroccidental    135.785633
# Name: Area, Length: 149, dtype: float64

# %%
area_barrios.head(10).plot.bar()
# Out:
# <Axes: xlabel='Barrio'>
